# %%
import os
import glob
import fnmatch
import pandas as pd
import matplotlib.pyplot as plt
import librosa
import librosa.display
import numpy as np
import seaborn as sns
import IPython.display as ipd
import random

from imblearn.over_sampling import SMOTE

from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Conv1D, Conv2D, SeparableConv1D, MaxPooling1D, MaxPooling2D
from tensorflow.keras.layers import Input, add, Flatten, Dense, BatchNormalization, Dropout, LSTM, GRU, SimpleRNN, LSTM
from tensorflow.keras.layers import GlobalMaxPooling1D, GlobalMaxPooling2D, Activation, LeakyReLU, ReLU, Dropout

from tensorflow.keras import regularizers
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adamax
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences

from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,matthews_corrcoef
from sklearn.metrics import cohen_kappa_score,roc_auc_score,confusion_matrix,classification_report

from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import ConfusionMatrixDisplay

# %%
df = pd.read_csv("hasta_etiketler.csv", sep=";")
df["Teshis"] = df["Teshis"].replace({
    "COPD4": "COPD",
    "COPD3": "COPD",
    "COPD2": "COPD",
    "COPD0": "COPD",
})
label_dict = dict(zip(df["ID"], df["Teshis"]))
label_dict["H001"] = "Healthy" 
label_dict
# Out:
# {'H001': 'Healthy',
#  'H002': 'COPD',
#  'H003': 'COPD',
#  'H004': 'COPD',
#  'H005': 'COPD',
#  'H006': 'COPD',
#  'H007': 'COPD',
#  'H008': 'COPD',
#  'H009': 'COPD',
#  'H010': 'COPD',
#  'H011': 'COPD',
#  'H012': 'COPD',
#  'H013': 'COPD',
#  'H014': 'COPD',
#  'H015': 'COPD',
#  'H016': 'COPD',
#  'H017': 'COPD1',
#  'H018': 'COPD',
#  'H019': 'Asthma',
#  'H020': 'Asthma',
#  'H021': 'COPD',
#  'H022': 'COPD',
#  'H023': 'COPD',
#  'H024': 'COPD',
#  'H025': 'COPD',
#  'H026': 'COPD',
#  'H027': 'Asthma',
#  'H028': 'COPD',
#  'H029': 'COPD1',
#  'H030': 'COPD',
#  'H031': 'COPD',
#  'H032': 'COPD',
#  'H033': 'COPD',
#  'H034': 'COPD',
#  'H035': 'COPD',
#  'H036': 'COPD',
#  'H037': 'COPD',
#  'H038': 'COPD',
#  'H039': 'COPD1',
#  'H040': 'COPD',
#  'H041': 'COPD',
#  'H042': 'COPD',
#  'H043': 'COPD1',
#  'H044': 'COPD',
#  'H045': 'COPD1',
#  'H046': 'Asthma',
#  'H047': 'Asthma',
#  'H048': 'Healthy',
#  'H049': 'Healthy',
#  'H050': 'COPD',
#  'H051': 'Asthma',
#  'H052': 'Healthy',
#  'H053': 'Healthy',
#  'H054': 'Healthy',
#  'H055': 'Healthy',
#  'H056': 'Healthy',
#  'H057': 'Healthy',
#  'H058': 'Healthy',
#  'H059': 'Healthy',
#  'H060': 'Healthy',
#  'H061': 'Healthy',
#  'H062': 'Healthy',
#  'H063': 'Healthy',
#  'H064': 'Healthy',
#  'H065': 'Healthy',
#  'H066': 'Healthy',
#  'H067': 'Healthy',
#  'H068': 'Healthy',
#  'H069': 'Healthy',
#  'H070': 'Healthy',
#  'H071': 'Healthy',
#  'H072': 'Healthy',
#  'H073': 'Healthy',
#  'H074': 'Healthy',
#  'H075': 'Healthy',
#  'H076': 'Healthy',
#  'H077': 'Healthy',
#  'H078': 'Healthy',
#  'H079': 'Healthy',
#  'H080': 'Healthy',
#  'H081': 'Healthy',
#  'H082': 'Healthy',
#  'H083': 'Healthy'}

# %%
asthma_data = "./Datalar/Asthma"
copd_data = "./Datalar/COPD4"
healthy_data = "./Datalar/Healthy"

print("Asthma files:", len(os.listdir(asthma_data)))
print("COPD files:", len(os.listdir(copd_data)))
print("Healthy files:", len(os.listdir(healthy_data)))
# Out:
# Asthma files: 96
# COPD files: 112
# Healthy files: 112

# %%
x = np.array([len(os.listdir(asthma_data)),
              len(os.listdir(copd_data)),
              len(os.listdir(healthy_data))])
labels = ['asthma', 'copd', 'heathy']
plt.pie(x, labels = labels, autopct = '%.0f%%', radius= 1.5, textprops={'fontsize': 16})
plt.show()

# %%
def augment_noise(audio, sr=None):
    noise = np.random.randn(len(audio))
    return audio + 0.005 * noise

def augment_pitch(audio, sr):
    return librosa.effects.pitch_shift(audio, sr=sr, n_steps=random.uniform(-2, 2))

def augment_speed(audio, sr):
    speed = random.uniform(0.9, 1.1)
    return librosa.effects.time_stretch(audio, rate=speed)

def apply_augmentations(audio, sr=22050):
    funcs = [
        lambda y: augment_noise(y),
        lambda y: augment_pitch(y, sr),
        lambda y: augment_speed(y, sr)
    ]
    func = random.choice(funcs)
    return func(audio)

# %%
def extract_mfcc(audio, sr=22050):
    mfcc = librosa.feature.mfcc(
        y=audio, sr=sr, n_mfcc=52, n_fft=2048, hop_length=512
    )
    return mfcc.T   # (time, 52)

# %%
class_folders = {
    "Asthma": asthma_data,
    "COPD": copd_data,
    "Healthy": healthy_data
}

X_features = []
y_labels = []

for label, folder in class_folders.items():
    for file in os.listdir(folder):
        path = os.path.join(folder, file)
        audio, sr = librosa.load(path, sr=22050)

        # Orijinal
        X_features.append(extract_mfcc(audio))
        y_labels.append(label)

        # Augmented
        audio_aug = apply_augmentations(audio)
        X_features.append(extract_mfcc(audio_aug))
        y_labels.append(label)

# %%
X_padded = pad_sequences(
    X_features,
    padding="post",
    dtype="float32"
)

X = np.array(X_padded)
y = np.array(y_labels)

# %%
le = LabelEncoder()
y_encoded = le.fit_transform(y)
y_categorical = to_categorical(y_encoded)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y_categorical, test_size=0.2, random_state=42
)

# %%
X_train_flat = X_train.reshape(X_train.shape[0], -1)
X_test_flat = X_test.reshape(X_test.shape[0], -1)

# %%
def build_mlp(input_dim, num_classes=3, lr=1e-4):
    model = Sequential([
        Dense(512, input_dim=input_dim, activation='relu'),
        BatchNormalization(),
        Dropout(0.4),

        Dense(256, activation='relu'),
        BatchNormalization(),
        Dropout(0.3),

        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.2),

        Dense(num_classes, activation='softmax')
    ])

    model.compile(
        optimizer="adam",
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %%
def build_lstm(input_shape, num_classes=3):
    model = Sequential()
    model.add(LSTM(128, return_sequences=False, input_shape=input_shape))
    model.add(Dropout(0.3))
    model.add(Dense(num_classes, activation="softmax"))
    model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
    return model

# %%
def build_svm(input_dim, num_classes=3, C=10, kernel='rbf'):
    model = SVC(
        C=C,
        kernel=kernel,
        gamma='scale',
        probability=True
    )
    return model

# %%
def build_knn(input_dim, num_classes=3, k=5):
    model = KNeighborsClassifier(n_neighbors=k)
    return model

# %%
def build_cnn(input_shape, num_classes=3):
    model = Sequential()
    model.add(Conv1D(64, kernel_size=3, activation='relu', input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(2))
    model.add(Dropout(0.3))

    model.add(Conv1D(128, kernel_size=3, activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(2))
    model.add(Dropout(0.3))

    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.4))
    model.add(Dense(num_classes, activation='softmax'))

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
seq_input = (X_train.shape[1], X_train.shape[2])  # (time, 52)
flat_input = X_train_flat.shape[1]
num_classes = y_train.shape[1]

# %%
models = {
    "MLP": build_mlp(flat_input, num_classes),
    "LSTM": build_lstm(seq_input, num_classes),
    "SVM": build_svm(flat_input, num_classes),
    "CNN": build_cnn(seq_input, num_classes),
    "KNN": build_knn(flat_input, num_classes),
}

results = {}

for name, model in models.items():
    print("\nTraining:", name)

    if name in ["MLP", "CNN", "LSTM"]:
        model.fit(X_train_flat if name=="MLP" else X_train,
                  y_train,
                  validation_data=(X_test_flat, y_test) if name=="MLP" else (X_test, y_test),
                  epochs=100, batch_size=32, verbose=0)

        preds = np.argmax(model.predict(X_test_flat if name=="MLP" else X_test), axis=1)

    else:  # SVM, KNN
        model.fit(X_train_flat, y_train.argmax(axis=1))
        preds = model.predict(X_test_flat)

    y_true = y_test.argmax(axis=1)
    f1 = f1_score(y_true, preds, average="weighted")
    results[name] = f1
    print("F1 Score:", f1)
    print(classification_report(y_true, preds))
# Out:
# c:\Users\MONSTER\Desktop\LungSoundAnlysis\LungSoundAnlysis\venv\lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\MONSTER\Desktop\LungSoundAnlysis\LungSoundAnlysis\venv\lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# c:\Users\MONSTER\Desktop\LungSoundAnlysis\LungSoundAnlysis\venv\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Training: MLP
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# F1 Score: 0.5144243777056277
#               precision    recall  f1-score   support
#
#            0       0.67      0.05      0.09        41
#            1       0.46      0.98      0.63        45
#            2       0.97      0.69      0.81        42
#
#     accuracy                           0.59       128
#    macro avg       0.70      0.57      0.51       128
# weighted avg       0.69      0.59      0.51       128
#
#
# Training: LSTM
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 299ms/step
# F1 Score: 0.1592085798816568
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        41
#            1       0.00      0.00      0.00        45
#            2       0.32      0.98      0.49        42
#
#     accuracy                           0.32       128
#    macro avg       0.11      0.33      0.16       128
# weighted avg       0.11      0.32      0.16       128
#
#
# Training: SVM
# c:\Users\MONSTER\Desktop\LungSoundAnlysis\LungSoundAnlysis\venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\MONSTER\Desktop\LungSoundAnlysis\LungSoundAnlysis\venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\MONSTER\Desktop\LungSoundAnlysis\LungSoundAnlysis\venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# F1 Score: 0.7199279379157428
#               precision    recall  f1-score   support
#
#            0       0.76      0.46      0.58        41
#            1       0.60      0.84      0.70        45
#            2       0.90      0.86      0.88        42
#
#     accuracy                           0.73       128
#    macro avg       0.75      0.72      0.72       128
# weighted avg       0.75      0.73      0.72       128
#
#
# Training: CNN
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# F1 Score: 0.8900337613493674
#               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88        41
#            1       0.88      0.82      0.85        45
#            2       0.93      0.95      0.94        42
#
#     accuracy                           0.89       128
#    macro avg       0.89      0.89      0.89       128
# weighted avg       0.89      0.89      0.89       128
#
#
# Training: KNN
# F1 Score: 0.6749141396709963
#               precision    recall  f1-score   support
#
#            0       0.53      0.66      0.59        41
#            1       0.64      0.47      0.54        45
#            2       0.89      0.93      0.91        42
#
#     accuracy                           0.68       128
#    macro avg       0.68      0.68      0.68       128
# weighted avg       0.68      0.68      0.67       128

# %%
cnn_model = build_cnn(seq_input, num_classes)
cnn_model.fit(X_train, y_train, validation_data=(X_test, y_test),
              epochs=50, batch_size=32, verbose=1)

y_pred_proba = cnn_model.predict(X_test)   # (N, 3)

y_pred = np.argmax(y_pred_proba, axis=1)   # (N,)
# Out:
# c:\Users\MONSTER\Desktop\LungSoundAnlysis\LungSoundAnlysis\venv\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 321ms/step - accuracy: 0.5625 - loss: 5.4361 - val_accuracy: 0.5781 - val_loss: 1.5944
# Epoch 2/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 316ms/step - accuracy: 0.6934 - loss: 0.7218 - val_accuracy: 0.6172 - val_loss: 0.7701
# Epoch 3/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 293ms/step - accuracy: 0.7773 - loss: 0.4936 - val_accuracy: 0.7109 - val_loss: 0.6498
# Epoch 4/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 324ms/step - accuracy: 0.8359 - loss: 0.3794 - val_accuracy: 0.6797 - val_loss: 0.6808
# Epoch 5/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 300ms/step - accuracy: 0.8574 - loss: 0.3167 - val_accuracy: 0.7500 - val_loss: 0.5933
# Epoch 6/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 305ms/step - accuracy: 0.9023 - loss: 0.2326 - val_accuracy: 0.8047 - val_loss: 0.5348
# Epoch 7/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 291ms/step - accuracy: 0.9062 - loss: 0.2012 - val_accuracy: 0.8281 - val_loss: 0.5292
# Epoch 8/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 291ms/step - accuracy: 0.9238 - loss: 0.1700 - val_accuracy: 0.8125 - val_loss: 0.4416
# Epoch 9/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 309ms/step - accuracy: 0.9551 - loss: 0.1330 - val_accuracy: 0.8047 - val_loss: 0.4262
# Epoch 10/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 289ms/step - accuracy: 0.9336 - loss: 0.1370 - val_accuracy: 0.8281 - val_loss: 0.4574
# Epoch 11/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 264ms/step - accuracy: 0.9727 - loss: 0.0862 - val_accuracy: 0.7891 - val_loss: 0.4580
# Epoch 12/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 275ms/step - accuracy: 0.9707 - loss: 0.0769 - val_accuracy: 0.7812 - val_loss: 0.5888
# Epoch 13/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 273ms/step - accuracy: 0.9727 - loss: 0.0896 - val_accuracy: 0.8359 - val_loss: 0.5009
# Epoch 14/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 279ms/step - accuracy: 0.9727 - loss: 0.0576 - val_accuracy: 0.7891 - val_loss: 0.5864
# Epoch 15/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 269ms/step - accuracy: 0.9668 - loss: 0.1060 - val_accuracy: 0.8281 - val_loss: 0.6388
# Epoch 16/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 290ms/step - accuracy: 0.9727 - loss: 0.0696 - val_accuracy: 0.8359 - val_loss: 0.5936
# Epoch 17/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 287ms/step - accuracy: 0.9707 - loss: 0.0736 - val_accuracy: 0.8125 - val_loss: 0.5527
# Epoch 18/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 279ms/step - accuracy: 0.9805 - loss: 0.0646 - val_accuracy: 0.8125 - val_loss: 0.9091
# Epoch 19/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 287ms/step - accuracy: 0.9707 - loss: 0.0867 - val_accuracy: 0.8438 - val_loss: 0.7997
# Epoch 20/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 310ms/step - accuracy: 0.9707 - loss: 0.0751 - val_accuracy: 0.8047 - val_loss: 0.9724
# Epoch 21/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 303ms/step - accuracy: 0.9805 - loss: 0.0567 - val_accuracy: 0.7656 - val_loss: 1.9130
# Epoch 22/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 271ms/step - accuracy: 0.9766 - loss: 0.0521 - val_accuracy: 0.8594 - val_loss: 0.4780
# Epoch 23/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 279ms/step - accuracy: 0.9668 - loss: 0.0989 - val_accuracy: 0.8672 - val_loss: 0.6661
# Epoch 24/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 307ms/step - accuracy: 0.9688 - loss: 0.1030 - val_accuracy: 0.8047 - val_loss: 1.2681
# Epoch 25/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 307ms/step - accuracy: 0.9805 - loss: 0.0565 - val_accuracy: 0.7891 - val_loss: 1.6696
# Epoch 26/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 296ms/step - accuracy: 0.9766 - loss: 0.0654 - val_accuracy: 0.8125 - val_loss: 1.9799
# Epoch 27/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 294ms/step - accuracy: 0.9688 - loss: 0.0834 - val_accuracy: 0.8359 - val_loss: 0.9523
# Epoch 28/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 280ms/step - accuracy: 0.9648 - loss: 0.1068 - val_accuracy: 0.8516 - val_loss: 0.8451
# Epoch 29/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 283ms/step - accuracy: 0.9785 - loss: 0.0791 - val_accuracy: 0.8438 - val_loss: 0.9211
# Epoch 30/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 274ms/step - accuracy: 0.9707 - loss: 0.0821 - val_accuracy: 0.8125 - val_loss: 0.8173
# Epoch 31/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 280ms/step - accuracy: 0.9629 - loss: 0.0818 - val_accuracy: 0.8594 - val_loss: 1.0764
# Epoch 32/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 289ms/step - accuracy: 0.9805 - loss: 0.0637 - val_accuracy: 0.8125 - val_loss: 1.3423
# Epoch 33/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 285ms/step - accuracy: 0.9805 - loss: 0.0453 - val_accuracy: 0.7656 - val_loss: 1.8695
# Epoch 34/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 301ms/step - accuracy: 0.9883 - loss: 0.0445 - val_accuracy: 0.8672 - val_loss: 1.1542
# Epoch 35/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 294ms/step - accuracy: 0.9844 - loss: 0.0582 - val_accuracy: 0.8516 - val_loss: 0.8198
# Epoch 36/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 298ms/step - accuracy: 0.9961 - loss: 0.0179 - val_accuracy: 0.8828 - val_loss: 0.9258
# Epoch 37/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 288ms/step - accuracy: 0.9883 - loss: 0.0252 - val_accuracy: 0.9062 - val_loss: 0.8227
# Epoch 38/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 273ms/step - accuracy: 0.9902 - loss: 0.0357 - val_accuracy: 0.8672 - val_loss: 1.0054
# Epoch 39/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 317ms/step - accuracy: 0.9746 - loss: 0.0532 - val_accuracy: 0.8516 - val_loss: 0.9132
# Epoch 40/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 302ms/step - accuracy: 0.9785 - loss: 0.1072 - val_accuracy: 0.8438 - val_loss: 1.1747
# Epoch 41/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 297ms/step - accuracy: 0.9785 - loss: 0.1335 - val_accuracy: 0.8828 - val_loss: 0.9923
# Epoch 42/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 287ms/step - accuracy: 0.9824 - loss: 0.0550 - val_accuracy: 0.8516 - val_loss: 1.0661
# Epoch 43/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 277ms/step - accuracy: 0.9590 - loss: 0.1540 - val_accuracy: 0.7812 - val_loss: 1.5841
# Epoch 44/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 284ms/step - accuracy: 0.9668 - loss: 0.1072 - val_accuracy: 0.8125 - val_loss: 1.0980
# Epoch 45/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 301ms/step - accuracy: 0.9707 - loss: 0.0899 - val_accuracy: 0.8359 - val_loss: 1.3489
# Epoch 46/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 302ms/step - accuracy: 0.9785 - loss: 0.0743 - val_accuracy: 0.8906 - val_loss: 0.7277
# Epoch 47/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 299ms/step - accuracy: 0.9766 - loss: 0.0743 - val_accuracy: 0.8828 - val_loss: 0.5985
# Epoch 48/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 289ms/step - accuracy: 0.9863 - loss: 0.0540 - val_accuracy: 0.8125 - val_loss: 0.8165
# Epoch 49/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 296ms/step - accuracy: 0.9824 - loss: 0.0556 - val_accuracy: 0.8203 - val_loss: 1.0505
# Epoch 50/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 295ms/step - accuracy: 0.9922 - loss: 0.0345 - val_accuracy: 0.8281 - val_loss: 0.9852
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=le.classes_,
            yticklabels=le.classes_)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix (CNN)")
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

y_true_bin = label_binarize(y_true, classes=[0,1,2])

plt.figure(figsize=(8, 6))

for i in range(3):
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_pred_proba[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{le.classes_[i]} (AUC={roc_auc:.2f})")

plt.plot([0,1], [0,1], "k--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve (CNN)")
plt.legend()
plt.show()
