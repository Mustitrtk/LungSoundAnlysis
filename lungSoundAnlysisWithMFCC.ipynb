# %%
import os
import glob
import fnmatch
import pandas as pd
import matplotlib.pyplot as plt
import librosa
import librosa.display
import numpy as np
import seaborn as sns
import IPython.display as ipd
import random

from imblearn.over_sampling import SMOTE

from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Conv1D, Conv2D, SeparableConv1D, MaxPooling1D, MaxPooling2D
from tensorflow.keras.layers import Input, add, Flatten, Dense, BatchNormalization, Dropout, LSTM, GRU, SimpleRNN, LSTM
from tensorflow.keras.layers import GlobalMaxPooling1D, GlobalMaxPooling2D, Activation, LeakyReLU, ReLU, Dropout

from tensorflow.keras import regularizers
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adamax
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences

from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,matthews_corrcoef
from sklearn.metrics import cohen_kappa_score,roc_auc_score,confusion_matrix,classification_report

# %%
df = pd.read_csv("hasta_etiketler.csv", sep=";")
df["Teshis"] = df["Teshis"].replace({
    "COPD4": "COPD",
    "COPD3": "COPD",
    "COPD2": "COPD",
    "COPD0": "COPD",
})
label_dict = dict(zip(df["ID"], df["Teshis"]))
label_dict["H001"] = "Healthy" 
label_dict
# Out:
# {'H001': 'Healthy',
#  'H002': 'COPD',
#  'H003': 'COPD',
#  'H004': 'COPD',
#  'H005': 'COPD',
#  'H006': 'COPD',
#  'H007': 'COPD',
#  'H008': 'COPD',
#  'H009': 'COPD',
#  'H010': 'COPD',
#  'H011': 'COPD',
#  'H012': 'COPD',
#  'H013': 'COPD',
#  'H014': 'COPD',
#  'H015': 'COPD',
#  'H016': 'COPD',
#  'H017': 'COPD1',
#  'H018': 'COPD',
#  'H019': 'Asthma',
#  'H020': 'Asthma',
#  'H021': 'COPD',
#  'H022': 'COPD',
#  'H023': 'COPD',
#  'H024': 'COPD',
#  'H025': 'COPD',
#  'H026': 'COPD',
#  'H027': 'Asthma',
#  'H028': 'COPD',
#  'H029': 'COPD1',
#  'H030': 'COPD',
#  'H031': 'COPD',
#  'H032': 'COPD',
#  'H033': 'COPD',
#  'H034': 'COPD',
#  'H035': 'COPD',
#  'H036': 'COPD',
#  'H037': 'COPD',
#  'H038': 'COPD',
#  'H039': 'COPD1',
#  'H040': 'COPD',
#  'H041': 'COPD',
#  'H042': 'COPD',
#  'H043': 'COPD1',
#  'H044': 'COPD',
#  'H045': 'COPD1',
#  'H046': 'Asthma',
#  'H047': 'Asthma',
#  'H048': 'Healthy',
#  'H049': 'Healthy',
#  'H050': 'COPD',
#  'H051': 'Asthma',
#  'H052': 'Healthy',
#  'H053': 'Healthy',
#  'H054': 'Healthy',
#  'H055': 'Healthy',
#  'H056': 'Healthy',
#  'H057': 'Healthy',
#  'H058': 'Healthy',
#  'H059': 'Healthy',
#  'H060': 'Healthy',
#  'H061': 'Healthy',
#  'H062': 'Healthy',
#  'H063': 'Healthy',
#  'H064': 'Healthy',
#  'H065': 'Healthy',
#  'H066': 'Healthy',
#  'H067': 'Healthy',
#  'H068': 'Healthy',
#  'H069': 'Healthy',
#  'H070': 'Healthy',
#  'H071': 'Healthy',
#  'H072': 'Healthy',
#  'H073': 'Healthy',
#  'H074': 'Healthy',
#  'H075': 'Healthy',
#  'H076': 'Healthy',
#  'H077': 'Healthy',
#  'H078': 'Healthy',
#  'H079': 'Healthy',
#  'H080': 'Healthy',
#  'H081': 'Healthy',
#  'H082': 'Healthy',
#  'H083': 'Healthy'}

# %%
asthma_data = "./Datalar/Asthma"
copd_data = "./Datalar/COPD4"
healthy_data = "./Datalar/Healthy"

print("Asthma files:", len(os.listdir(asthma_data)))
print("COPD files:", len(os.listdir(copd_data)))
print("Healthy files:", len(os.listdir(healthy_data)))
# Out:
# Asthma files: 96
# COPD files: 112
# Healthy files: 112

# %%
x = np.array([len(os.listdir(asthma_data)),
              len(os.listdir(copd_data)),
              len(os.listdir(healthy_data))])
labels = ['asthma', 'copd', 'heathy']
plt.pie(x, labels = labels, autopct = '%.0f%%', radius= 1.5, textprops={'fontsize': 16})
plt.show()

# %%
def augment_noise(audio, sr=None):
    noise = np.random.randn(len(audio))
    return audio + 0.005 * noise

def augment_pitch(audio, sr):
    return librosa.effects.pitch_shift(audio, sr=sr, n_steps=random.uniform(-2, 2))

def augment_speed(audio, sr):
    speed = random.uniform(0.9, 1.1)
    return librosa.effects.time_stretch(audio, rate=speed)

def apply_augmentations(audio, sr=22050):
    funcs = [
        lambda y: augment_noise(y),
        lambda y: augment_pitch(y, sr),
        lambda y: augment_speed(y, sr)
    ]
    func = random.choice(funcs)
    return func(audio)

# %%
def extract_mfcc(audio, sr=22050):
    mfcc = librosa.feature.mfcc(
        y=audio, sr=sr, n_mfcc=52, n_fft=2048, hop_length=512
    )
    return mfcc.T   # (time, 52)

# %%
class_folders = {
    "Asthma": asthma_data,
    "COPD": copd_data,
    "Healthy": healthy_data
}

X_features = []
y_labels = []

for label, folder in class_folders.items():
    for file in os.listdir(folder):
        path = os.path.join(folder, file)
        audio, sr = librosa.load(path, sr=22050)

        # Orijinal
        X_features.append(extract_mfcc(audio))
        y_labels.append(label)

        # Augmented
        audio_aug = apply_augmentations(audio)
        X_features.append(extract_mfcc(audio_aug))
        y_labels.append(label)

# %%
X_padded = pad_sequences(
    X_features,
    padding="post",
    dtype="float32"
)

X = np.array(X_padded)
y = np.array(y_labels)

# %%
le = LabelEncoder()
y_encoded = le.fit_transform(y)
y_categorical = to_categorical(y_encoded)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y_categorical, test_size=0.2, random_state=42
)

# %%
X_train_flat = X_train.reshape(X_train.shape[0], -1)
X_test_flat = X_test.reshape(X_test.shape[0], -1)

# %%
def build_mlp(input_dim, num_classes=3):
    model = Sequential([
        Dense(256, activation='relu', input_dim=input_dim),
        Dropout(0.4),
        Dense(128, activation='relu'),
        Dropout(0.3),
        Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
def build_lstm(input_shape, num_classes=3):
    model = Sequential()
    model.add(LSTM(128, return_sequences=False, input_shape=input_shape))
    model.add(Dropout(0.3))
    model.add(Dense(num_classes, activation="softmax"))
    model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
    return model

# %%
def build_rnn(input_shape, num_classes=3):
    model = Sequential([
        SimpleRNN(128, return_sequences=False, input_shape=input_shape),
        Dropout(0.3),
        Dense(64, activation="relu"),
        Dropout(0.2),
        Dense(num_classes, activation="softmax")
    ])
    model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
    return model

# %%
def build_cnn(input_shape, num_classes=3):
    model = Sequential()
    model.add(Conv1D(64, kernel_size=3, activation='relu', input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(2))
    model.add(Dropout(0.3))

    model.add(Conv1D(128, kernel_size=3, activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(2))
    model.add(Dropout(0.3))

    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.4))
    model.add(Dense(num_classes, activation='softmax'))

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
seq_input = (X_train.shape[1], X_train.shape[2])  # (time, 52)
flat_input = X_train_flat.shape[1]
num_classes = y_train.shape[1]

# %%
models = {
    "MLP": build_mlp(flat_input, num_classes),
    "LSTM": build_lstm(seq_input, num_classes),
    "RNN": build_rnn(seq_input, num_classes),
    "CNN": build_cnn(seq_input, num_classes),
}

results = {}

for name, model in models.items():
    print("\nTraining:", name)

    if name == "MLP":
        model.fit(X_train_flat, y_train, validation_data=(X_test_flat, y_test),
                  epochs=100, batch_size=32, verbose=0)
        preds = np.argmax(model.predict(X_test_flat), axis=1)
    else:
        model.fit(X_train, y_train, validation_data=(X_test, y_test),
                  epochs=100, batch_size=32, verbose=0)
        preds = np.argmax(model.predict(X_test), axis=1)

    y_true = np.argmax(y_test, axis=1)
    f1 = f1_score(y_true, preds, average="weighted")
    results[name] = f1

    print("F1 Score:", f1)
    print(classification_report(y_true, preds))
# Out:
# c:\Users\MONSTER\Desktop\LungSoundAnlysis\LungSoundAnlysis\venv\lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\MONSTER\Desktop\LungSoundAnlysis\LungSoundAnlysis\venv\lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# c:\Users\MONSTER\Desktop\LungSoundAnlysis\LungSoundAnlysis\venv\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Training: MLP
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# F1 Score: 0.1592085798816568
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        41
#            1       0.00      0.00      0.00        45
#            2       0.32      0.98      0.49        42
#
#     accuracy                           0.32       128
#    macro avg       0.11      0.33      0.16       128
# weighted avg       0.11      0.32      0.16       128
#
#
# Training: LSTM
# c:\Users\MONSTER\Desktop\LungSoundAnlysis\LungSoundAnlysis\venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\MONSTER\Desktop\LungSoundAnlysis\LungSoundAnlysis\venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\MONSTER\Desktop\LungSoundAnlysis\LungSoundAnlysis\venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 198ms/step
# F1 Score: 0.5730950146493317
#               precision    recall  f1-score   support
#
#            0       1.00      0.05      0.09        41
#            1       0.52      0.96      0.68        45
#            2       0.91      0.95      0.93        42
#
#     accuracy                           0.66       128
#    macro avg       0.81      0.65      0.57       128
# weighted avg       0.80      0.66      0.57       128
#
#
# Training: RNN
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# F1 Score: 0.24103079490291263
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        41
#            1       0.33      0.42      0.37        45
#            2       0.27      0.45      0.34        42
#
#     accuracy                           0.30       128
#    macro avg       0.20      0.29      0.24       128
# weighted avg       0.20      0.30      0.24       128
#
#
# Training: CNN
# c:\Users\MONSTER\Desktop\LungSoundAnlysis\LungSoundAnlysis\venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\MONSTER\Desktop\LungSoundAnlysis\LungSoundAnlysis\venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\MONSTER\Desktop\LungSoundAnlysis\LungSoundAnlysis\venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# F1 Score: 0.8259800578350065
#               precision    recall  f1-score   support
#
#            0       0.79      0.73      0.76        41
#            1       0.78      0.78      0.78        45
#            2       0.91      0.98      0.94        42
#
#     accuracy                           0.83       128
#    macro avg       0.83      0.83      0.83       128
# weighted avg       0.83      0.83      0.83       128

# %%
# Modeli eğit
cnn_model = build_cnn(seq_input, num_classes)
cnn_model.fit(X_train, y_train, validation_data=(X_test, y_test),
              epochs=50, batch_size=32, verbose=1)

# Olasılık tahminleri
y_pred_proba = cnn_model.predict(X_test)   # (N, 3)

# Sınıf tahminleri
y_pred = np.argmax(y_pred_proba, axis=1)   # (N,)
# Out:
# Epoch 1/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 317ms/step - accuracy: 0.5332 - loss: 7.7151 - val_accuracy: 0.5625 - val_loss: 4.1191
# Epoch 2/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 331ms/step - accuracy: 0.7891 - loss: 1.1911 - val_accuracy: 0.6875 - val_loss: 1.2776
# Epoch 3/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 299ms/step - accuracy: 0.8672 - loss: 0.4384 - val_accuracy: 0.6719 - val_loss: 0.8407
# Epoch 4/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 271ms/step - accuracy: 0.8848 - loss: 0.3330 - val_accuracy: 0.6172 - val_loss: 1.1276
# Epoch 5/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 274ms/step - accuracy: 0.9258 - loss: 0.2832 - val_accuracy: 0.7266 - val_loss: 0.9347
# Epoch 6/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 247ms/step - accuracy: 0.9512 - loss: 0.1425 - val_accuracy: 0.7500 - val_loss: 0.7249
# Epoch 7/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 237ms/step - accuracy: 0.9395 - loss: 0.2220 - val_accuracy: 0.7422 - val_loss: 0.6998
# Epoch 8/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 252ms/step - accuracy: 0.9492 - loss: 0.1311 - val_accuracy: 0.8438 - val_loss: 0.5441
# Epoch 9/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 243ms/step - accuracy: 0.9590 - loss: 0.1114 - val_accuracy: 0.8516 - val_loss: 0.6547
# Epoch 10/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 236ms/step - accuracy: 0.9707 - loss: 0.0768 - val_accuracy: 0.7969 - val_loss: 0.8567
# Epoch 11/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 254ms/step - accuracy: 0.9688 - loss: 0.0673 - val_accuracy: 0.8359 - val_loss: 0.7534
# Epoch 12/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 237ms/step - accuracy: 0.9609 - loss: 0.0957 - val_accuracy: 0.8359 - val_loss: 0.7705
# Epoch 13/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 245ms/step - accuracy: 0.9688 - loss: 0.0820 - val_accuracy: 0.8281 - val_loss: 1.0065
# Epoch 14/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 245ms/step - accuracy: 0.9688 - loss: 0.0652 - val_accuracy: 0.8203 - val_loss: 1.0895
# Epoch 15/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 237ms/step - accuracy: 0.9746 - loss: 0.0569 - val_accuracy: 0.8516 - val_loss: 1.2752
# Epoch 16/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 243ms/step - accuracy: 0.9668 - loss: 0.0768 - val_accuracy: 0.8281 - val_loss: 1.0457
# Epoch 17/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 241ms/step - accuracy: 0.9668 - loss: 0.1005 - val_accuracy: 0.8359 - val_loss: 1.3166
# Epoch 18/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 244ms/step - accuracy: 0.9902 - loss: 0.1496 - val_accuracy: 0.8047 - val_loss: 1.8668
# Epoch 19/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 247ms/step - accuracy: 0.9668 - loss: 0.1289 - val_accuracy: 0.8594 - val_loss: 1.6604
# Epoch 20/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 247ms/step - accuracy: 0.9727 - loss: 0.1130 - val_accuracy: 0.7734 - val_loss: 1.2723
# Epoch 21/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 241ms/step - accuracy: 0.9746 - loss: 0.0895 - val_accuracy: 0.8359 - val_loss: 1.2345
# Epoch 22/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 256ms/step - accuracy: 0.9766 - loss: 0.0639 - val_accuracy: 0.8828 - val_loss: 0.9359
# Epoch 23/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 293ms/step - accuracy: 0.9883 - loss: 0.0478 - val_accuracy: 0.8359 - val_loss: 0.9933
# Epoch 24/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 288ms/step - accuracy: 0.9766 - loss: 0.0687 - val_accuracy: 0.8359 - val_loss: 1.1223
# Epoch 25/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 289ms/step - accuracy: 0.9668 - loss: 0.1120 - val_accuracy: 0.8047 - val_loss: 1.3263
# Epoch 26/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 285ms/step - accuracy: 0.9824 - loss: 0.0563 - val_accuracy: 0.5156 - val_loss: 6.3553
# Epoch 27/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 277ms/step - accuracy: 0.9727 - loss: 0.0722 - val_accuracy: 0.6094 - val_loss: 3.6290
# Epoch 28/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 277ms/step - accuracy: 0.9844 - loss: 0.0408 - val_accuracy: 0.7969 - val_loss: 1.2058
# Epoch 29/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 279ms/step - accuracy: 0.9883 - loss: 0.0357 - val_accuracy: 0.8281 - val_loss: 1.5418
# Epoch 30/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 280ms/step - accuracy: 0.9844 - loss: 0.0480 - val_accuracy: 0.7812 - val_loss: 2.1732
# Epoch 31/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 270ms/step - accuracy: 0.9746 - loss: 0.1101 - val_accuracy: 0.8281 - val_loss: 1.8996
# Epoch 32/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 287ms/step - accuracy: 0.9785 - loss: 0.0777 - val_accuracy: 0.7969 - val_loss: 2.8165
# Epoch 33/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 280ms/step - accuracy: 0.9688 - loss: 0.1425 - val_accuracy: 0.6094 - val_loss: 5.4415
# Epoch 34/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 284ms/step - accuracy: 0.9707 - loss: 0.1208 - val_accuracy: 0.7969 - val_loss: 1.2594
# Epoch 35/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 270ms/step - accuracy: 0.9746 - loss: 0.1309 - val_accuracy: 0.8438 - val_loss: 0.9193
# Epoch 36/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 265ms/step - accuracy: 0.9629 - loss: 0.1663 - val_accuracy: 0.7500 - val_loss: 2.0061
# Epoch 37/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 290ms/step - accuracy: 0.9629 - loss: 0.1116 - val_accuracy: 0.8438 - val_loss: 1.0091
# Epoch 38/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 296ms/step - accuracy: 0.9727 - loss: 0.1184 - val_accuracy: 0.8125 - val_loss: 1.4792
# Epoch 39/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 281ms/step - accuracy: 0.9785 - loss: 0.0789 - val_accuracy: 0.7578 - val_loss: 1.8809
# Epoch 40/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 289ms/step - accuracy: 0.9785 - loss: 0.1041 - val_accuracy: 0.8047 - val_loss: 1.4183
# Epoch 41/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 293ms/step - accuracy: 0.9805 - loss: 0.0786 - val_accuracy: 0.7734 - val_loss: 1.4650
# Epoch 42/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 290ms/step - accuracy: 0.9785 - loss: 0.0763 - val_accuracy: 0.8359 - val_loss: 1.6442
# Epoch 43/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 308ms/step - accuracy: 0.9785 - loss: 0.0649 - val_accuracy: 0.7969 - val_loss: 1.1541
# Epoch 44/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 293ms/step - accuracy: 0.9766 - loss: 0.0688 - val_accuracy: 0.8516 - val_loss: 1.0508
# Epoch 45/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 285ms/step - accuracy: 0.9805 - loss: 0.0596 - val_accuracy: 0.8828 - val_loss: 1.1664
# Epoch 46/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 277ms/step - accuracy: 0.9941 - loss: 0.0196 - val_accuracy: 0.8359 - val_loss: 1.9686
# Epoch 47/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 276ms/step - accuracy: 0.9883 - loss: 0.0520 - val_accuracy: 0.8203 - val_loss: 2.9484
# Epoch 48/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 277ms/step - accuracy: 0.9824 - loss: 0.0633 - val_accuracy: 0.8125 - val_loss: 2.7190
# Epoch 49/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 284ms/step - accuracy: 0.9883 - loss: 0.0526 - val_accuracy: 0.8125 - val_loss: 2.4162
# Epoch 50/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 272ms/step - accuracy: 0.9883 - loss: 0.0800 - val_accuracy: 0.7969 - val_loss: 2.2245
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=le.classes_,
            yticklabels=le.classes_)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix (CNN)")
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

y_true_bin = label_binarize(y_true, classes=[0,1,2])

plt.figure(figsize=(8, 6))

for i in range(3):
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_pred_proba[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{le.classes_[i]} (AUC={roc_auc:.2f})")

plt.plot([0,1], [0,1], "k--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve (CNN)")
plt.legend()
plt.show()
