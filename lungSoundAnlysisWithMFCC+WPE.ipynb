# %%
import os
import glob
import fnmatch
import pandas as pd
import matplotlib.pyplot as plt
import librosa
import librosa.display
import numpy as np
import seaborn as sns
import IPython.display as ipd
import random

from imblearn.over_sampling import SMOTE

from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Conv1D, Conv2D, SeparableConv1D, MaxPooling1D, MaxPooling2D
from tensorflow.keras.layers import Input, add, Flatten, Dense, BatchNormalization, Dropout, LSTM, GRU, SimpleRNN, LSTM
from tensorflow.keras.layers import GlobalMaxPooling1D, GlobalMaxPooling2D, Activation, LeakyReLU, ReLU, Dropout

from tensorflow.keras import regularizers
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adamax
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences

from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,matthews_corrcoef
from sklearn.metrics import cohen_kappa_score,roc_auc_score,confusion_matrix,classification_report

from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import ConfusionMatrixDisplay

# %%
df = pd.read_csv("hasta_etiketler.csv", sep=";")
df["Teshis"] = df["Teshis"].replace({
    "COPD4": "COPD",
    "COPD3": "COPD",
    "COPD2": "COPD",
    "COPD0": "COPD",
})
label_dict = dict(zip(df["ID"], df["Teshis"]))
label_dict["H001"] = "Healthy" 
label_dict
# Out:
# {'H001': 'Healthy',
#  'H002': 'COPD',
#  'H003': 'COPD',
#  'H004': 'COPD',
#  'H005': 'COPD',
#  'H006': 'COPD',
#  'H007': 'COPD',
#  'H008': 'COPD',
#  'H009': 'COPD',
#  'H010': 'COPD',
#  'H011': 'COPD',
#  'H012': 'COPD',
#  'H013': 'COPD',
#  'H014': 'COPD',
#  'H015': 'COPD',
#  'H016': 'COPD',
#  'H017': 'COPD1',
#  'H018': 'COPD',
#  'H019': 'Asthma',
#  'H020': 'Asthma',
#  'H021': 'COPD',
#  'H022': 'COPD',
#  'H023': 'COPD',
#  'H024': 'COPD',
#  'H025': 'COPD',
#  'H026': 'COPD',
#  'H027': 'Asthma',
#  'H028': 'COPD',
#  'H029': 'COPD1',
#  'H030': 'COPD',
#  'H031': 'COPD',
#  'H032': 'COPD',
#  'H033': 'COPD',
#  'H034': 'COPD',
#  'H035': 'COPD',
#  'H036': 'COPD',
#  'H037': 'COPD',
#  'H038': 'COPD',
#  'H039': 'COPD1',
#  'H040': 'COPD',
#  'H041': 'COPD',
#  'H042': 'COPD',
#  'H043': 'COPD1',
#  'H044': 'COPD',
#  'H045': 'COPD1',
#  'H046': 'Asthma',
#  'H047': 'Asthma',
#  'H048': 'Healthy',
#  'H049': 'Healthy',
#  'H050': 'COPD',
#  'H051': 'Asthma',
#  'H052': 'Healthy',
#  'H053': 'Healthy',
#  'H054': 'Healthy',
#  'H055': 'Healthy',
#  'H056': 'Healthy',
#  'H057': 'Healthy',
#  'H058': 'Healthy',
#  'H059': 'Healthy',
#  'H060': 'Healthy',
#  'H061': 'Healthy',
#  'H062': 'Healthy',
#  'H063': 'Healthy',
#  'H064': 'Healthy',
#  'H065': 'Healthy',
#  'H066': 'Healthy',
#  'H067': 'Healthy',
#  'H068': 'Healthy',
#  'H069': 'Healthy',
#  'H070': 'Healthy',
#  'H071': 'Healthy',
#  'H072': 'Healthy',
#  'H073': 'Healthy',
#  'H074': 'Healthy',
#  'H075': 'Healthy',
#  'H076': 'Healthy',
#  'H077': 'Healthy',
#  'H078': 'Healthy',
#  'H079': 'Healthy',
#  'H080': 'Healthy',
#  'H081': 'Healthy',
#  'H082': 'Healthy',
#  'H083': 'Healthy'}

# %%
asthma_data = "./Datalar/Asthma"
copd_data = "./Datalar/COPD4"
healthy_data = "./Datalar/Healthy"

print("Asthma files:", len(os.listdir(asthma_data)))
print("COPD files:", len(os.listdir(copd_data)))
print("Healthy files:", len(os.listdir(healthy_data)))
# Out:
# Asthma files: 96
# COPD files: 112
# Healthy files: 112

# %%
x = np.array([len(os.listdir(asthma_data)),
              len(os.listdir(copd_data)),
              len(os.listdir(healthy_data))])
labels = ['asthma', 'copd', 'heathy']
plt.pie(x, labels = labels, autopct = '%.0f%%', radius= 1.5, textprops={'fontsize': 16})
plt.show()

# %%
def augment_noise(audio, sr=None):
    noise = np.random.randn(len(audio))
    return audio + 0.005 * noise

def augment_pitch(audio, sr):
    return librosa.effects.pitch_shift(audio, sr=sr, n_steps=random.uniform(-2, 2))

def augment_speed(audio, sr):
    speed = random.uniform(0.9, 1.1)
    return librosa.effects.time_stretch(audio, rate=speed)

def apply_augmentations(audio, sr=22050):
    funcs = [
        lambda y: augment_noise(y),
        lambda y: augment_pitch(y, sr),
        lambda y: augment_speed(y, sr)
    ]
    func = random.choice(funcs)
    return func(audio)

# %%
import nara_wpe.wpe as wpe


def apply_wpe(audio, sr=22050):

    audio = np.expand_dims(audio, axis=0)   # (mic, samples)

    enhanced = wpe.wpe(
        audio,
        taps=10,
        delay=3,
        iterations=5
    )

    return enhanced[0]



def extract_mfcc(audio, sr=22050):
    audio = apply_wpe(audio, sr)

    mfcc = librosa.feature.mfcc(
        y=audio, sr=sr,
        n_mfcc=52, n_fft=2048, hop_length=512
    )
    return mfcc.T

# %%
class_folders = {
    "Asthma": asthma_data,
    "COPD": copd_data,
    "Healthy": healthy_data
}

X_features = []
y_labels = []

for label, folder in class_folders.items():
    for file in os.listdir(folder):
        path = os.path.join(folder, file)
        audio, sr = librosa.load(path, sr=22050)

        # Orijinal
        X_features.append(extract_mfcc(audio))
        y_labels.append(label)

        # Augmented
        audio_aug = apply_augmentations(audio)
        X_features.append(extract_mfcc(audio_aug))
        y_labels.append(label)

# %%
X_padded = pad_sequences(
    X_features,
    padding="post",
    dtype="float32"
)

X = np.array(X_padded)
y = np.array(y_labels)

# %%
le = LabelEncoder()
y_encoded = le.fit_transform(y)
y_categorical = to_categorical(y_encoded)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y_categorical, test_size=0.2, random_state=42
)

# %%
X_train_flat = X_train.reshape(X_train.shape[0], -1)
X_test_flat = X_test.reshape(X_test.shape[0], -1)

# %%
def build_mlp(input_dim, num_classes=3, lr=1e-4):
    model = Sequential([
        Dense(512, input_dim=input_dim, activation='relu'),
        BatchNormalization(),
        Dropout(0.4),

        Dense(256, activation='relu'),
        BatchNormalization(),
        Dropout(0.3),

        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.2),

        Dense(num_classes, activation='softmax')
    ])

    model.compile(
        optimizer="adam",
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %%
def build_lstm(input_shape, num_classes=3):
    model = Sequential()
    model.add(LSTM(128, return_sequences=False, input_shape=input_shape))
    model.add(Dropout(0.3))
    model.add(Dense(num_classes, activation="softmax"))
    model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
    return model

# %%
def build_svm(input_dim, num_classes=3, C=10, kernel='rbf'):
    model = SVC(
        C=C,
        kernel=kernel,
        gamma='scale',
        probability=True
    )
    return model

# %%
def build_knn(input_dim, num_classes=3, k=5):
    model = KNeighborsClassifier(n_neighbors=k)
    return model

# %%
def build_cnn(input_shape, num_classes=3):
    model = Sequential()
    model.add(Conv1D(64, kernel_size=3, activation='relu', input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(2))
    model.add(Dropout(0.3))

    model.add(Conv1D(128, kernel_size=3, activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(2))
    model.add(Dropout(0.3))

    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.4))
    model.add(Dense(num_classes, activation='softmax'))

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
seq_input = (X_train.shape[1], X_train.shape[2])  # (time, 52)
flat_input = X_train_flat.shape[1]
num_classes = y_train.shape[1]

# %%
models = {
    "MLP": build_mlp(flat_input, num_classes),
    "LSTM": build_lstm(seq_input, num_classes),
    "SVM": build_svm(flat_input, num_classes),
    "CNN": build_cnn(seq_input, num_classes),
    "KNN": build_knn(flat_input, num_classes),
}

results = {}

for name, model in models.items():
    print("\nTraining:", name)

    if name in ["MLP", "CNN", "LSTM"]:
        model.fit(X_train_flat if name=="MLP" else X_train,
                  y_train,
                  validation_data=(X_test_flat, y_test) if name=="MLP" else (X_test, y_test),
                  epochs=100, batch_size=32, verbose=0)

        preds = np.argmax(model.predict(X_test_flat if name=="MLP" else X_test), axis=1)

    else:  # SVM, KNN
        model.fit(X_train_flat, y_train.argmax(axis=1))
        preds = model.predict(X_test_flat)

    y_true = y_test.argmax(axis=1)
    f1 = f1_score(y_true, preds, average="weighted")
    results[name] = f1
    print("F1 Score:", f1)
    print(classification_report(y_true, preds))

# KNN ======================================================================

""" print("\nTraining: KNN")
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_flat, y_train.argmax(axis=1))

knn_preds = knn.predict(X_test_flat)

knn_f1 = f1_score(y_test.argmax(axis=1), knn_preds, average="weighted")
results["KNN"] = knn_f1

print("F1 Score:", knn_f1)
print(classification_report(y_test.argmax(axis=1), knn_preds))

cm = confusion_matrix(y_test.argmax(axis=1), knn_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title("KNN Confusion Matrix")
plt.show() """



# SVM ======================================================================

""" print("\nTraining: SVM")
svm = SVC(kernel='rbf', probability=True)
svm.fit(X_train_flat, y_train.argmax(axis=1))

svm_preds = svm.predict(X_test_flat)

svm_f1 = f1_score(y_test.argmax(axis=1), svm_preds, average="weighted")
results["SVM"] = svm_f1

print("F1 Score:", svm_f1)
print(classification_report(y_test.argmax(axis=1), svm_preds))

cm = confusion_matrix(y_test.argmax(axis=1), svm_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title("SVM Confusion Matrix")
plt.show() """
# Out:
# c:\Users\MONSTER\Desktop\LungSoundAnlysis\LungSoundAnlysis\venv\lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\MONSTER\Desktop\LungSoundAnlysis\LungSoundAnlysis\venv\lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# c:\Users\MONSTER\Desktop\LungSoundAnlysis\LungSoundAnlysis\venv\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Training: MLP
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# F1 Score: 0.7358744579562595
#               precision    recall  f1-score   support
#
#            0       0.65      0.68      0.67        41
#            1       0.73      0.96      0.83        45
#            2       0.92      0.57      0.71        42
#
#     accuracy                           0.74       128
#    macro avg       0.77      0.74      0.73       128
# weighted avg       0.77      0.74      0.74       128
#
#
# Training: LSTM
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 240ms/step
# F1 Score: 0.19921875000000003
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        41
#            1       0.35      1.00      0.52        45
#            2       1.00      0.02      0.05        42
#
#     accuracy                           0.36       128
#    macro avg       0.45      0.34      0.19       128
# weighted avg       0.45      0.36      0.20       128
#
#
# Training: SVM
# c:\Users\MONSTER\Desktop\LungSoundAnlysis\LungSoundAnlysis\venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\MONSTER\Desktop\LungSoundAnlysis\LungSoundAnlysis\venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\MONSTER\Desktop\LungSoundAnlysis\LungSoundAnlysis\venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# F1 Score: 0.7114108571556994
#               precision    recall  f1-score   support
#
#            0       0.71      0.54      0.61        41
#            1       0.59      0.76      0.66        45
#            2       0.90      0.83      0.86        42
#
#     accuracy                           0.71       128
#    macro avg       0.73      0.71      0.71       128
# weighted avg       0.73      0.71      0.71       128
#
#
# Training: CNN
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# F1 Score: 0.763780525030525
#               precision    recall  f1-score   support
#
#            0       0.65      0.78      0.71        41
#            1       0.70      0.71      0.70        45
#            2       1.00      0.79      0.88        42
#
#     accuracy                           0.76       128
#    macro avg       0.78      0.76      0.76       128
# weighted avg       0.78      0.76      0.76       128
#
#
# Training: KNN
# F1 Score: 0.6499219691768681
#               precision    recall  f1-score   support
#
#            0       0.51      0.54      0.52        41
#            1       0.59      0.58      0.58        45
#            2       0.85      0.83      0.84        42
#
#     accuracy                           0.65       128
#    macro avg       0.65      0.65      0.65       128
# weighted avg       0.65      0.65      0.65       128
# ' print("\nTraining: SVM")\nsvm = SVC(kernel=\'rbf\', probability=True)\nsvm.fit(X_train_flat, y_train.argmax(axis=1))\n\nsvm_preds = svm.predict(X_test_flat)\n\nsvm_f1 = f1_score(y_test.argmax(axis=1), svm_preds, average="weighted")\nresults["SVM"] = svm_f1\n\nprint("F1 Score:", svm_f1)\nprint(classification_report(y_test.argmax(axis=1), svm_preds))\n\ncm = confusion_matrix(y_test.argmax(axis=1), svm_preds)\ndisp = ConfusionMatrixDisplay(confusion_matrix=cm)\ndisp.plot()\nplt.title("SVM Confusion Matrix")\nplt.show() '

# %%
cnn_model = build_cnn(seq_input, num_classes)
cnn_model.fit(X_train, y_train, validation_data=(X_test, y_test),
              epochs=100, batch_size=32, verbose=1)

y_pred_proba = cnn_model.predict(X_test)   # (N, 3)

y_pred = np.argmax(y_pred_proba, axis=1)   # (N,)
# Out:
# Epoch 1/100
# c:\Users\MONSTER\Desktop\LungSoundAnlysis\LungSoundAnlysis\venv\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 239ms/step - accuracy: 0.5020 - loss: 7.4705 - val_accuracy: 0.5000 - val_loss: 5.1822
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 234ms/step - accuracy: 0.6934 - loss: 1.5984 - val_accuracy: 0.5938 - val_loss: 1.1616
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 217ms/step - accuracy: 0.7012 - loss: 0.6996 - val_accuracy: 0.5391 - val_loss: 1.5853
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 217ms/step - accuracy: 0.7578 - loss: 0.7062 - val_accuracy: 0.5312 - val_loss: 1.1386
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 214ms/step - accuracy: 0.7773 - loss: 0.5534 - val_accuracy: 0.6641 - val_loss: 0.8097
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 214ms/step - accuracy: 0.7676 - loss: 0.5256 - val_accuracy: 0.7266 - val_loss: 0.7416
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 216ms/step - accuracy: 0.7852 - loss: 0.5050 - val_accuracy: 0.7422 - val_loss: 0.7371
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 221ms/step - accuracy: 0.8516 - loss: 0.3891 - val_accuracy: 0.7812 - val_loss: 0.7067
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 212ms/step - accuracy: 0.8457 - loss: 0.3678 - val_accuracy: 0.7422 - val_loss: 0.6454
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 221ms/step - accuracy: 0.8730 - loss: 0.3008 - val_accuracy: 0.6875 - val_loss: 0.7956
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 216ms/step - accuracy: 0.9023 - loss: 0.2461 - val_accuracy: 0.7500 - val_loss: 0.7495
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 219ms/step - accuracy: 0.9199 - loss: 0.1942 - val_accuracy: 0.7812 - val_loss: 0.6872
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 218ms/step - accuracy: 0.9238 - loss: 0.1915 - val_accuracy: 0.7031 - val_loss: 0.7225
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 218ms/step - accuracy: 0.9258 - loss: 0.1837 - val_accuracy: 0.7188 - val_loss: 0.9125
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 224ms/step - accuracy: 0.9199 - loss: 0.1940 - val_accuracy: 0.6719 - val_loss: 0.8170
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 227ms/step - accuracy: 0.9316 - loss: 0.1650 - val_accuracy: 0.7734 - val_loss: 0.7731
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 220ms/step - accuracy: 0.9551 - loss: 0.1176 - val_accuracy: 0.6953 - val_loss: 0.9307
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 219ms/step - accuracy: 0.9453 - loss: 0.1238 - val_accuracy: 0.7500 - val_loss: 0.7579
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 220ms/step - accuracy: 0.9570 - loss: 0.0930 - val_accuracy: 0.7656 - val_loss: 0.7802
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 218ms/step - accuracy: 0.9512 - loss: 0.1187 - val_accuracy: 0.7656 - val_loss: 0.8440
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 217ms/step - accuracy: 0.9531 - loss: 0.1174 - val_accuracy: 0.7344 - val_loss: 1.1976
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 221ms/step - accuracy: 0.9648 - loss: 0.1074 - val_accuracy: 0.7656 - val_loss: 0.9951
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - accuracy: 0.9492 - loss: 0.1264 - val_accuracy: 0.7891 - val_loss: 0.6987
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - accuracy: 0.9570 - loss: 0.1283 - val_accuracy: 0.8438 - val_loss: 0.5548
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 216ms/step - accuracy: 0.9668 - loss: 0.0880 - val_accuracy: 0.8359 - val_loss: 0.5745
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 221ms/step - accuracy: 0.9707 - loss: 0.0672 - val_accuracy: 0.8203 - val_loss: 0.7440
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 217ms/step - accuracy: 0.9531 - loss: 0.1554 - val_accuracy: 0.7500 - val_loss: 1.1268
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 214ms/step - accuracy: 0.9512 - loss: 0.1340 - val_accuracy: 0.7812 - val_loss: 1.0138
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 216ms/step - accuracy: 0.9512 - loss: 0.1236 - val_accuracy: 0.6953 - val_loss: 2.0440
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 214ms/step - accuracy: 0.9590 - loss: 0.1151 - val_accuracy: 0.7656 - val_loss: 1.0405
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 220ms/step - accuracy: 0.9590 - loss: 0.1575 - val_accuracy: 0.6797 - val_loss: 1.7408
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 214ms/step - accuracy: 0.9590 - loss: 0.0915 - val_accuracy: 0.8047 - val_loss: 0.5835
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 214ms/step - accuracy: 0.9648 - loss: 0.0985 - val_accuracy: 0.7891 - val_loss: 0.7841
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - accuracy: 0.9512 - loss: 0.1185 - val_accuracy: 0.8281 - val_loss: 0.7193
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 216ms/step - accuracy: 0.9648 - loss: 0.0915 - val_accuracy: 0.8203 - val_loss: 0.8416
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 216ms/step - accuracy: 0.9727 - loss: 0.0628 - val_accuracy: 0.8047 - val_loss: 1.0527
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 217ms/step - accuracy: 0.9648 - loss: 0.1180 - val_accuracy: 0.7656 - val_loss: 1.8621
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 217ms/step - accuracy: 0.9688 - loss: 0.0799 - val_accuracy: 0.7500 - val_loss: 1.2610
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - accuracy: 0.9746 - loss: 0.0684 - val_accuracy: 0.7734 - val_loss: 1.0292
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 216ms/step - accuracy: 0.9766 - loss: 0.0789 - val_accuracy: 0.8125 - val_loss: 0.7860
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 214ms/step - accuracy: 0.9863 - loss: 0.0482 - val_accuracy: 0.7969 - val_loss: 1.2488
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 222ms/step - accuracy: 0.9824 - loss: 0.0518 - val_accuracy: 0.8672 - val_loss: 0.8484
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 219ms/step - accuracy: 0.9785 - loss: 0.0713 - val_accuracy: 0.8281 - val_loss: 1.1747
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 218ms/step - accuracy: 0.9844 - loss: 0.0405 - val_accuracy: 0.7969 - val_loss: 1.4956
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 213ms/step - accuracy: 0.9863 - loss: 0.0486 - val_accuracy: 0.8672 - val_loss: 1.0435
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 219ms/step - accuracy: 0.9863 - loss: 0.0556 - val_accuracy: 0.8438 - val_loss: 0.7954
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 216ms/step - accuracy: 0.9766 - loss: 0.0922 - val_accuracy: 0.8438 - val_loss: 1.0729
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 218ms/step - accuracy: 0.9746 - loss: 0.0704 - val_accuracy: 0.8281 - val_loss: 0.8429
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 215ms/step - accuracy: 0.9805 - loss: 0.0541 - val_accuracy: 0.8359 - val_loss: 0.6728
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 220ms/step - accuracy: 0.9766 - loss: 0.0683 - val_accuracy: 0.8203 - val_loss: 0.8517
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 213ms/step - accuracy: 0.9824 - loss: 0.0444 - val_accuracy: 0.8516 - val_loss: 0.8773
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 216ms/step - accuracy: 0.9824 - loss: 0.0481 - val_accuracy: 0.8047 - val_loss: 0.9720
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 220ms/step - accuracy: 0.9844 - loss: 0.0480 - val_accuracy: 0.7656 - val_loss: 1.6452
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 227ms/step - accuracy: 0.9941 - loss: 0.0210 - val_accuracy: 0.7734 - val_loss: 1.6459
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 224ms/step - accuracy: 0.9805 - loss: 0.0678 - val_accuracy: 0.7812 - val_loss: 1.5717
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 219ms/step - accuracy: 0.9727 - loss: 0.1130 - val_accuracy: 0.6484 - val_loss: 3.3486
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 217ms/step - accuracy: 0.9688 - loss: 0.0670 - val_accuracy: 0.6484 - val_loss: 3.4189
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 218ms/step - accuracy: 0.9746 - loss: 0.0969 - val_accuracy: 0.8047 - val_loss: 1.0724
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 216ms/step - accuracy: 0.9785 - loss: 0.0846 - val_accuracy: 0.8125 - val_loss: 1.1987
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 217ms/step - accuracy: 0.9844 - loss: 0.0601 - val_accuracy: 0.8750 - val_loss: 0.5693
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 217ms/step - accuracy: 0.9883 - loss: 0.0245 - val_accuracy: 0.8516 - val_loss: 0.4773
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - accuracy: 0.9883 - loss: 0.0515 - val_accuracy: 0.8438 - val_loss: 0.7187
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 217ms/step - accuracy: 0.9922 - loss: 0.0307 - val_accuracy: 0.8359 - val_loss: 0.7817
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 218ms/step - accuracy: 0.9844 - loss: 0.0566 - val_accuracy: 0.8516 - val_loss: 0.7519
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 221ms/step - accuracy: 0.9941 - loss: 0.0213 - val_accuracy: 0.7969 - val_loss: 1.1264
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 221ms/step - accuracy: 0.9824 - loss: 0.0683 - val_accuracy: 0.7812 - val_loss: 1.3406
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 219ms/step - accuracy: 0.9629 - loss: 0.1189 - val_accuracy: 0.7969 - val_loss: 1.2922
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 225ms/step - accuracy: 0.9668 - loss: 0.1042 - val_accuracy: 0.7891 - val_loss: 1.3437
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 214ms/step - accuracy: 0.9609 - loss: 0.1530 - val_accuracy: 0.7734 - val_loss: 1.3867
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 219ms/step - accuracy: 0.9512 - loss: 0.1934 - val_accuracy: 0.7266 - val_loss: 2.2678
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 214ms/step - accuracy: 0.9688 - loss: 0.1106 - val_accuracy: 0.7812 - val_loss: 1.3491
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 219ms/step - accuracy: 0.9629 - loss: 0.1195 - val_accuracy: 0.8281 - val_loss: 0.8833
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 219ms/step - accuracy: 0.9629 - loss: 0.1268 - val_accuracy: 0.7109 - val_loss: 2.3107
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - accuracy: 0.9727 - loss: 0.1543 - val_accuracy: 0.8047 - val_loss: 0.9324
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - accuracy: 0.9746 - loss: 0.1102 - val_accuracy: 0.8125 - val_loss: 1.3719
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 222ms/step - accuracy: 0.9551 - loss: 0.1380 - val_accuracy: 0.8125 - val_loss: 1.1114
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 222ms/step - accuracy: 0.9492 - loss: 0.2667 - val_accuracy: 0.8047 - val_loss: 0.9984
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 217ms/step - accuracy: 0.9727 - loss: 0.1163 - val_accuracy: 0.7422 - val_loss: 1.7306
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 217ms/step - accuracy: 0.9707 - loss: 0.1322 - val_accuracy: 0.7656 - val_loss: 1.6612
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - accuracy: 0.9766 - loss: 0.0906 - val_accuracy: 0.8047 - val_loss: 1.4004
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 217ms/step - accuracy: 0.9785 - loss: 0.0719 - val_accuracy: 0.8281 - val_loss: 1.0179
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 219ms/step - accuracy: 0.9844 - loss: 0.0509 - val_accuracy: 0.8125 - val_loss: 1.4678
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 216ms/step - accuracy: 0.9883 - loss: 0.0410 - val_accuracy: 0.7500 - val_loss: 1.5514
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 219ms/step - accuracy: 0.9883 - loss: 0.0510 - val_accuracy: 0.8203 - val_loss: 1.1185
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - accuracy: 0.9941 - loss: 0.0167 - val_accuracy: 0.8125 - val_loss: 1.1315
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 218ms/step - accuracy: 0.9902 - loss: 0.0322 - val_accuracy: 0.7969 - val_loss: 1.2852
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - accuracy: 0.9902 - loss: 0.0138 - val_accuracy: 0.8047 - val_loss: 1.2863
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 221ms/step - accuracy: 0.9844 - loss: 0.0377 - val_accuracy: 0.7969 - val_loss: 1.5075
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 217ms/step - accuracy: 0.9941 - loss: 0.0165 - val_accuracy: 0.7891 - val_loss: 1.6646
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 228ms/step - accuracy: 0.9863 - loss: 0.0370 - val_accuracy: 0.7812 - val_loss: 1.6297
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 216ms/step - accuracy: 0.9902 - loss: 0.0363 - val_accuracy: 0.8047 - val_loss: 1.0758
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - accuracy: 0.9844 - loss: 0.0346 - val_accuracy: 0.8203 - val_loss: 0.8469
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - accuracy: 0.9902 - loss: 0.0371 - val_accuracy: 0.8594 - val_loss: 0.8053
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 222ms/step - accuracy: 0.9941 - loss: 0.0674 - val_accuracy: 0.8359 - val_loss: 0.9620
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 220ms/step - accuracy: 0.9883 - loss: 0.0606 - val_accuracy: 0.8047 - val_loss: 1.3756
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - accuracy: 0.9902 - loss: 0.0473 - val_accuracy: 0.8125 - val_loss: 1.0435
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 214ms/step - accuracy: 0.9863 - loss: 0.0707 - val_accuracy: 0.7891 - val_loss: 1.5301
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 216ms/step - accuracy: 0.9688 - loss: 0.1677 - val_accuracy: 0.8047 - val_loss: 1.2596
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 220ms/step - accuracy: 0.9824 - loss: 0.0607 - val_accuracy: 0.8359 - val_loss: 1.1004
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 216ms/step - accuracy: 0.9805 - loss: 0.0530 - val_accuracy: 0.7578 - val_loss: 1.8383
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=le.classes_,
            yticklabels=le.classes_)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix (CNN)")
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

y_true_bin = label_binarize(y_true, classes=[0,1,2])

plt.figure(figsize=(8, 6))

for i in range(3):
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_pred_proba[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{le.classes_[i]} (AUC={roc_auc:.2f})")

plt.plot([0,1], [0,1], "k--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve (CNN)")
plt.legend()
plt.show()
